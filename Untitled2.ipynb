# %%
# !pip install TensorFlow
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
# Out:
# ...
#   Obtaining dependency information for TensorFlow from https://files.pythonhosted.org/packages/1b/66/2f47c39cfedb29188d82555d0184a619a0bf8234fd5e5301940efb0aa464/tensorflow-2.13.0-cp39-cp39-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for tensorflow-intel==2.13.0 from https://files.pythonhosted.org/packages/2b/ad/d3a2e335004d178e0599cf8aff6c2a92cd21eb9789358fb8f3f951009930/tensorflow_intel-2.13.0-cp39-cp39-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/126.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/126.5 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/126.5 kB ? eta -:--:--
#      -------- ---------------------------- 30.7/126.5 kB 435.7 kB/s eta 0:00:01
#      -------------------------------- --- 112.6/126.5 kB 819.2 kB/s eta 0:00:01
#      ---------------------------------- - 122.9/126.5 kB 901.1 kB/s eta 0:00:01
# ...

# %%
# Charger les données MNIST
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Normaliser les images en les ramenant dans l'intervalle [0, 1]
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# ...
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)), # Aplatir l'image 28x28 en un vecteur de taille 784
    Dense(128, activation='relu'),   # Couche dense avec 128 neurones et fonction d'activation ReLU
    Dense(10, activation='softmax')  # Couche de sortie avec 10 neurones (un pour chaque chiffre) et fonction d'activation softmax
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 4ms/step - loss: 0.2574 - accuracy: 0.9259
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1116 - accuracy: 0.9663
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0759 - accuracy: 0.9768
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0582 - accuracy: 0.9822
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0449 - accuracy: 0.9862

# %%
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print("Précision sur l'ensemble de test :", test_accuracy)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0855 - accuracy: 0.9762
# Précision sur l'ensemble de test : 0.9761999845504761
