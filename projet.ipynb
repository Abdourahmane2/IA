# %%
print('repondre aux questions par vrai ou faux')
import pandas as pd
from sklearn.tree import DecisionTreeClassifier  # por entrainer le model avec la methode fit
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder # fonction permet de transformer me sobjets en 1 et 0 booleen


def transform(df): #transformer les boolen en int 1 pour vrai et 0 pour False
    for c in df.columns:
        if df[c].dtype=='object': 
            df[c] = df[c].fillna('N')
            lbl = LabelEncoder()
            lbl.fit(list(df[c].values))
            df[c] = lbl.transform(df[c].values)
    return df

database = pd.read_csv('zoo.csv')
database['animal'] = database['animal'].apply(lambda x :x.replace('b' , ''))
database.head(5)
# Out:
# repondre aux questions par vrai ou faux
#        animal      hair  feathers      eggs      milk  airborne   aquatic  \
# 0  'aardvark'   b'true'  b'false'  b'false'   b'true'  b'false'  b'false'
# 1  'antelope'   b'true'  b'false'  b'false'   b'true'  b'false'  b'false'
# 2       'ass'  b'false'  b'false'   b'true'  b'false'  b'false'   b'true'
# 3       'ear'   b'true'  b'false'  b'false'   b'true'  b'false'  b'false'
# 4       'oar'   b'true'  b'false'  b'false'   b'true'  b'false'  b'false'
#
#    predator  toothed backbone  breathes  venomous      fins  legs      tail  \
# 0   b'true'  b'true'  b'true'   b'true'  b'false'  b'false'   4.0  b'false'
# 1  b'false'  b'true'  b'true'   b'true'  b'false'  b'false'   4.0   b'true'
# 2   b'true'  b'true'  b'true'  b'false'  b'false'   b'true'   0.0   b'true'
# 3   b'true'  b'true'  b'true'   b'true'  b'false'  b'false'   4.0  b'false'
# 4   b'true'  b'true'  b'true'   b'true'  b'false'  b'false'   4.0   b'true'
#
# ...
